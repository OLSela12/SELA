# %% [markdown]
# <a href="https://colab.research.google.com/github/john-s-butler-dit/Numerical-Analysis-Python/blob/master/Chapter%2003%20-%20Runge%20Kutta/301_2nd%20Order%20Runge%20Kutta%20Population%20Equations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Application of 2nd order Runge Kutta to Populations Equations
#
# This notebook implements the 2nd Order Runge Kutta method for three different population intial value problems.
#
# # 2nd Order Runge Kutta
# The general 2nd Order Runge Kutta method for to the first order differential equation
# \begin{equation} y^{'} = f(t,y) \end{equation}
# numerical approximates $y$ the at time point $t_i$ as $w_i$
# with the  formula:
# \begin{equation} w_{i+1}=w_i+\frac{h}{2}\big[k_1+k_2],\end{equation}
# for $i=0,...,N-1$, where
# \begin{equation}k_1=f(t_i,w_i),\end{equation}
# and
# \begin{equation}k_2=f(t_i+h,w_i+hk_1),\end{equation}
# and $h$ is the stepsize.
#
# To illustrate the method we will apply it to three intial value problems:
# ## 1. Linear
# Consider the linear population Differential Equation
# \begin{equation} y^{'}=0.1y, \ \ (2000 \leq t \leq 2020), \end{equation}
# with the initial condition,
# \begin{equation}y(2000)=6.\end{equation}
#
# ## 2. Non-Linear Population Equation
# Consider the non-linear population Differential Equation
# \begin{equation} y^{'}=0.2y-0.01y^2, \ \ (2000 \leq t \leq 2020), \end{equation}
# with the initial condition,
# \begin{equation}y(2000)=6.\end{equation}
#
# ## 3. Non-Linear Population Equation with an oscillation
# Consider the non-linear population Differential Equation with an oscillation
# \begin{equation} y^{'}=0.2y-0.01y^2+\sin(2\pi t), \ \ (2000 \leq t \leq 2020), \end{equation}
# with the initial condition,
# \begin{equation}y(2000)=6.\end{equation}

# %% [markdown]
# #### Setting up Libraries

# %%
## Library
import numpy as np
import math 
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt # side-stepping mpl backend
import matplotlib.gridspec as gridspec # subplots
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Discrete Interval
# The continuous time $a\leq t \leq b $ is discretised into $N$ points seperated by a constant stepsize
# \begin{equation} h=\frac{b-a}{N}.\end{equation}
# Here, the interval is $2000\leq t \leq 2020,$
# \begin{equation} h=\frac{2020-2000}{200}=0.1.\end{equation}
# This gives the 201 discrete points:
# \begin{equation} t_0=2000, \ t_1=2000.1, \ ... t_{200}=2020. \end{equation}
# This is generalised to
# \begin{equation} t_i=2000+i0.1, \ \ \ i=0,1,...,200.\end{equation}
# The plot below shows the discrete time steps:

# %%
N=200
t_end=2020.0
t_start=2000.0
h=((t_end-t_start)/N)
t=np.arange(t_start,t_end+h/2,h)
fig = plt.figure(figsize=(10,4))
plt.plot(t,0*t,'o:',color='red')
plt.title('Illustration of discrete time points for h=%s'%(h))
plt.show()

# %% [markdown]
# # 1. Linear Population Equation
# ## Exact Solution
# The linear population equation
# \begin{equation} y^{'}=0.1y, \ \ (2000 \leq t \leq 2020), \end{equation}
# with the initial condition,
# \begin{equation} y(2000)=6.\end{equation}
# has a known exact (analytic) solution
# \begin{equation} y=6e^{0.1(t-2000)}. \end{equation}
#
# ## Specific 2nd Order Runge Kutta
# To write the specific 2nd Order Runge Kutta method for the linear population equation we need
# \begin{equation}f(t,y)=0.1y.\end{equation}

# %%
def linfun(t,w):
    ftw=0.1*w
    return ftw

# %% [markdown]
# this gives
# \begin{equation}k_1=f(t_i,w_i)=0.lw_i,\end{equation}
# \begin{equation}k_2=f(t_i+h,w_i+hk_1)=0.1(w_i+hk_1),\end{equation}
# and the difference equation
# \begin{equation}w_{i+1}=w_{i}+\frac{h}{2}(k_1+k_2),\end{equation}
# for $i=0,...,199$, where $w_i$ is the numerical approximation of $y$ at time $t_i$, with step size $h$ and the initial condition
# \begin{equation}w_0=6.\end{equation}

# %%
w=np.zeros(N+1)
w[0]=6.0
## 2nd Order Runge Kutta
for k in range (0,N):
    k1=linfun(t[k],w[k])
    k2=linfun(t[k]+h,w[k]+h*k1)
    w[k+1]=w[k]+h/2*(k1+k2)

# %% [markdown]
# ## Plotting Results

# %%
y=6*np.exp(0.1*(t-2000))
fig = plt.figure(figsize=(8,4))
plt.plot(t,w,'o:',color='purple',label='Runge Kutta')
plt.plot(t,y,'s:',color='black',label='Exact')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Table
# The table below shows the time, the Runge Kutta numerical approximation, $w$,  the exact solution, $y$, and the exact error $|y(t_i)-w_i|$ for the linear population equation:

# %%
d = {'time t_i': t[0:10],    'Runge Kutta':w[0:10],'Exact (y)':y[0:10],'Exact Error':np.abs(np.round(y[0:10]-w[0:10],10))}
df = pd.DataFrame(data=d)
df
# Out:
#    time t_i  Runge Kutta  Exact (y)  Exact Error
# 0    2000.0     6.000000   6.000000     0.000000
# 1    2000.1     6.060300   6.060301     0.000001
# 2    2000.2     6.121206   6.121208     0.000002
# 3    2000.3     6.182724   6.182727     0.000003
# 4    2000.4     6.244861   6.244865     0.000004
# 5    2000.5     6.307621   6.307627     0.000005
# 6    2000.6     6.371013   6.371019     0.000006
# 7    2000.7     6.435042   6.435049     0.000007
# 8    2000.8     6.499714   6.499722     0.000009
# 9    2000.9     6.565036   6.565046     0.000010

# %% [markdown]
# ## 2. Non-Linear Population Equation
# \begin{equation} y^{'}=0.2y-0.01y^2, \ \ (2000 \leq t \leq 2020), \end{equation}
# with the initial condition,
# \begin{equation}y(2000)=6.\end{equation}
# ## Specific 2nd Order Runge Kutta for the Non-Linear Population Equation
# To write the specific 2nd Order Runge Kutta method we need
# \begin{equation}f(t,y)=0.2y-0.01y^2,\end{equation}
# this gives
# \begin{equation}k_1=f(t_i,w_i)=0.2w_i-0.01w_i^2,\end{equation}
# \begin{equation}k_2=f(t_i+h,w_i+hk_1)=0.2(w_i+hk_1)-0.01(w_i+hk_1)^2,\end{equation}
# and the difference equation
# \begin{equation}w_{i+1}=w_{i}+\frac{h}{2}(k_1+k_2),\end{equation}
# for $i=0,...,199$, where $w_i$ is the numerical approximation of $y$ at time $t_i$, with step size $h$ and the initial condition
# \begin{equation}w_0=6.\end{equation}

# %%
def nonlinfun(t,w):
    ftw=0.2*w-0.01*w*w
    return ftw

# %%
w=np.zeros(N+1)
w[0]=6.0
## 2nd Order Runge Kutta
for k in range (0,N):
    k1=nonlinfun(t[k],w[k])
    k2=nonlinfun(t[k]+h,w[k]+h*k1)
    w[k+1]=w[k]+h/2*(k1+k2)

# %% [markdown]
# ## Results
# The plot below shows the Runge Kutta numerical approximation, $w$ (circles) for the non-linear population equation:

# %%
fig = plt.figure(figsize=(8,4))
plt.plot(t,w,'o:',color='purple',label='Runge Kutta')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Table
# The table below shows the time and the Runge Kutta numerical approximation, $w$,  for the non-linear population equation:

# %%
d = {'time t_i': t[0:10], 
     'Runge Kutta':w[0:10]}
df = pd.DataFrame(data=d)
df
# Out:
#    time t_i  Runge Kutta
# 0    2000.0     6.000000
# 1    2000.1     6.084332
# 2    2000.2     6.169328
# 3    2000.3     6.254977
# 4    2000.4     6.341270
# 5    2000.5     6.428197
# 6    2000.6     6.515747
# 7    2000.7     6.603909
# 8    2000.8     6.692672
# 9    2000.9     6.782025

# %% [markdown]
# ## 3. Non-Linear Population Equation with an oscilation
# \begin{equation} y^{'}=0.2y-0.01y^2+\sin(2\pi t), \ \ (2000 \leq t \leq 2020), \end{equation}
# with the initial condition,
# \begin{equation}y(2000)=6.\end{equation}
#
# ## Specific 2nd Order Runge Kutta for the Non-Linear Population Equation with an oscilation
# To write the specific 2nd Order Runge Kutta difference equation for the intial value problem we need
# \begin{equation}f(t,y)=0.2y-0.01y^2+\sin(2\pi t),\end{equation}
# which gives
# \begin{equation}k_1=f(t_i,w_i)=0.2w_i-0.01w_i^2+\sin(2\pi t_i),\end{equation}
# \begin{equation}k_2=f(t_i+h,w_i+hk_1)=0.2(w_i+hk_1)-0.01(w_i+hk_1)^2+\sin(2\pi (t_i+h)),\end{equation}
# and the difference equation
# \begin{equation}w_{i+1}=w_{i}+\frac{h}{2}(k_1+k_2),\end{equation}
# for $i=0,...,199$, where $w_i$ is the numerical approximation of $y$ at time $t_i$, with step size $h$ and the initial condition
# \begin{equation}w_0=6.\end{equation}

# %%
def nonlin_oscfun(t,w):
    ftw=0.2*w-0.01*w*w+np.sin(2*np.math.pi*t)
    return ftw

# %%
w=np.zeros(N+1)
w[0]=6.0
## 2nd Order Runge Kutta
for k in range (0,N):
    k1=nonlin_oscfun(t[k],w[k])
    k2=nonlin_oscfun(t[k]+h,w[k]+h*k1)
    w[k+1]=w[k]+h/2*(k1+k2)

# %% [markdown]
# ## Results
# The plot below shows the 2nd order Runge Kutta numerical approximation, $w$ (circles) for the non-linear population equation:

# %%
fig = plt.figure(figsize=(8,4))
plt.plot(t,w,'o:',color='purple',label='Taylor')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ## Table
# The table below shows the time and the 2nd order Runge Kutta numerical approximation, $w$,  for the non-linear population equation:

# %%
d = {'time t_i': t[0:10], 
     'Runge Kutta':w[0:10]}
df = pd.DataFrame(data=d)
df
# Out:
#    time t_i  Runge Kutta
# 0    2000.0     6.000000
# 1    2000.1     6.113722
# 2    2000.2     6.276109
# 3    2000.3     6.458005
# 4    2000.4     6.623032
# 5    2000.5     6.741504
# 6    2000.6     6.801784
# 7    2000.7     6.814712
# 8    2000.8     6.809444
# 9    2000.9     6.822305

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the exact solution
def exact_solution(t):
    return 2 * (t - 1) + np.exp(-t)

# Define the differential equation f(t, y) = 2t - y
def f(t, y):
    return 2 * t - y

# Midpoint method (RK2) implementation
def rk2_midpoint(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h/2, y[i] + h/2 * k1)
        y[i + 1] = y[i] + h * k2
        t[i + 1] = t[i] + h
    return t, y

# Parameters
t0 = 0
y0 = -1
h = 0.1
steps = 10

# Time points for exact solution
t_exact = np.linspace(0, 1, 10)
y_exact = exact_solution(t_exact)

# RK2 (Midpoint Method) solution
t_rk2, y_rk2 = rk2_midpoint(f, t0, y0, h, steps)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(t_exact, y_exact, label='Exact Solution', color='blue')
plt.plot(t_rk2, y_rk2, 'o--', label='RK2 Approximation', color='red')
#plt.title("Exact Solution vs RK2 Approximation")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.legend()
#plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Define the exact solution
def exact_solution(t):
    return 2 * (t - 1) + np.exp(-t)

# Define the differential equation f(t, y) = 2t - y
def f(t, y):
    return 2 * t - y

# Midpoint method (RK2) implementation
def rk2_midpoint(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        y[i + 1] = y[i] + h * k2
        t[i + 1] = t[i] + h
    return t, y

# Parameters
t0 = 0
y0 = -1
h = 0.1
steps = 10  # You can change this to display more rows in the table

# Compute the exact solution and RK2 solution
t_rk2, y_rk2 = rk2_midpoint(f, t0, y0, h, steps)
y_exact_rk2 = exact_solution(t_rk2)

# Compute the error
error_rk2 = np.abs(y_exact_rk2 - y_rk2)

# Create a table using pandas
data = {
    't_i': t_rk2,
    'y_exact': y_exact_rk2,
    'y_approximation': y_rk2,
    'Error': error_rk2
}

df = pd.DataFrame(data)

# Display the table
print(df)

# Plot the results for better visualization
plt.figure(figsize=(10, 6))
plt.plot(t_rk2, y_exact_rk2, label='Exact Solution', color='blue')
plt.plot(t_rk2, y_rk2, 'o--', label='RK2 (Midpoint) Approximation', color='red')
plt.title("Exact Solution vs RK2 (Midpoint) Approximation")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#     t_i   y_exact  y_approximation     Error
# 0   0.0 -1.000000        -1.000000  0.000000
# 1   0.1 -0.895163        -0.895000  0.000163
# 2   0.2 -0.781269        -0.780975  0.000294
# 3   0.3 -0.659182        -0.658782  0.000399
# 4   0.4 -0.529680        -0.529198  0.000482
# 5   0.5 -0.393469        -0.392924  0.000545
# 6   0.6 -0.251188        -0.250596  0.000592
# 7   0.7 -0.103415        -0.102790  0.000625
# 8   0.8  0.049329         0.049975  0.000646
# 9   0.9  0.206570         0.207228  0.000658
# 10  1.0  0.367879         0.368541  0.000662

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the exact solution
def exact_solution(t):
    return 2 * (t - 1) + np.exp(-t)

# Define the differential equation f(t, y) = 2t - y
def f(t, y):
    return 2 * t - y

# RK4 method implementation
def rk4_method(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        k3 = f(t[i] + h / 2, y[i] + h / 2 * k2)
        k4 = f(t[i] + h, y[i] + h * k3)
        y[i + 1] = y[i] + h / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        t[i + 1] = t[i] + h
    return t, y

# Parameters
t0 = 0
y0 = -1
h = 0.1
steps = 10

# Time points for exact solution
t_exact = np.linspace(0, 1, 10)
y_exact = exact_solution(t_exact)

# RK4 solution
t_rk4, y_rk4 = rk4_method(f, t0, y0, h, steps)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(t_exact, y_exact, label='Exact Solution', color='blue')
plt.plot(t_rk4, y_rk4, 'o--', label='RK4 Approximation', color='red')
#plt.title("Exact Solution vs RK4 Approximation")
plt.xlabel("t")
plt.ylabel("y(t)")
plt.legend()
#plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the exact solution
def exact_solution(t):
    return 2 * (t - 1) + np.exp(-t)

# Define the differential equation f(t, y) = 2t - y
def f(t, y):
    return 2 * t - y

# Euler method implementation
def euler(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        y[i + 1] = y[i] + h * f(t[i], y[i])
        t[i + 1] = t[i] + h
    return t, y

# Midpoint method (RK2) implementation
def rk2_midpoint(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        y[i + 1] = y[i] + h * k2
        t[i + 1] = t[i] + h
    return t, y

# RK3 method implementation
def rk3(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        k3 = f(t[i] + h, y[i] - h * k1 + 2 * h * k2)
        y[i + 1] = y[i] + h / 6 * (k1 + 4 * k2 + k3)
        t[i + 1] = t[i] + h
    return t, y

# RK4 method implementation
def rk4(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        k3 = f(t[i] + h / 2, y[i] + h / 2 * k2)
        k4 = f(t[i] + h, y[i] + h * k3)
        y[i + 1] = y[i] + h / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        t[i + 1] = t[i] + h
    return t, y

# Parameters
t0 = 0
y0 = -1
h = 0.2
steps = 10

# Time points for exact solution
t_exact = np.linspace(0, 1, 10)
y_exact = exact_solution(t_exact)

# Compute solutions using Euler, RK2, RK3, and RK4 methods
t_euler, y_euler = euler(f, t0, y0, h, steps)
t_rk2, y_rk2 = rk2_midpoint(f, t0, y0, h, steps)
t_rk3, y_rk3 = rk3(f, t0, y0, h, steps)
t_rk4, y_rk4 = rk4(f, t0, y0, h, steps)

# Plot the results
plt.figure(figsize=(12, 8))

# Exact Solution
plt.plot(t_exact, y_exact, label='Exact Solution', color='black', linewidth=2)

# Euler Method
plt.plot(t_euler, y_euler, 'o--', label='Euler Method', color='blue', markersize=4)

# RK2 Method
plt.plot(t_rk2, y_rk2, 's--', label='RK2 (Midpoint)', color='red', markersize=4)

# RK3 Method
plt.plot(t_rk3, y_rk3, 'd--', label='RK3', color='green', markersize=4)

# RK4 Method
plt.plot(t_rk4, y_rk4, 'x--', label='RK4', color='purple', markersize=4)

# Formatting the plot
#plt.title('Exact Solution vs Euler, RK2, RK3, and RK4 Methods', fontsize=16)
plt.xlabel('t', fontsize=14)
plt.ylabel('y(t)', fontsize=14)
plt.legend()
#plt.grid(True)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the exact solution
def exact_solution(t):
    return 2 * (t - 1) + np.exp(-t)

# Define the differential equation f(t, y) = 2t - y
def f(t, y):
    return 2 * t - y

# Midpoint method (RK2) implementation
def rk2_midpoint(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        y[i + 1] = y[i] + h * k2
        t[i + 1] = t[i] + h
    return t, y

# RK3 method implementation
def rk3(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        k3 = f(t[i] + h, y[i] - h * k1 + 2 * h * k2)
        y[i + 1] = y[i] + h / 6 * (k1 + 4 * k2 + k3)
        t[i + 1] = t[i] + h
    return t, y

# RK4 method implementation
def rk4(f, t0, y0, h, steps):
    t = np.zeros(steps + 1)
    y = np.zeros(steps + 1)
    t[0] = t0
    y[0] = y0
    for i in range(steps):
        k1 = f(t[i], y[i])
        k2 = f(t[i] + h / 2, y[i] + h / 2 * k1)
        k3 = f(t[i] + h / 2, y[i] + h / 2 * k2)
        k4 = f(t[i] + h, y[i] + h * k3)
        y[i + 1] = y[i] + h / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
        t[i + 1] = t[i] + h
    return t, y

# Parameters
t0 = 0
y0 = -1
h = 0.1
steps = 5

# Time points for exact solution
t_exact = np.linspace(0, 1, 5)
y_exact = exact_solution(t_exact)

# Compute solutions using RK2, RK3, and RK4 methods
t_rk2, y_rk2 = rk2_midpoint(f, t0, y0, h, steps)
t_rk3, y_rk3 = rk3(f, t0, y0, h, steps)
t_rk4, y_rk4 = rk4(f, t0, y0, h, steps)

# Plot the results
plt.figure(figsize=(12, 8))

# Exact Solution
plt.plot(t_exact, y_exact, label='Exact Solution', color='black', linewidth=2)

# RK2 Method
plt.plot(t_rk2, y_rk2, 's--', label='RK2 (Midpoint)', color='red', markersize=4)

# RK3 Method
plt.plot(t_rk3, y_rk3, 'd--', label='RK3', color='green', markersize=4)

# RK4 Method
plt.plot(t_rk4, y_rk4, 'x--', label='RK4', color='purple', markersize=4)

# Formatting the plot
#plt.title('Exact Solution vs RK2, RK3, and RK4 Methods', fontsize=16)
plt.xlabel('t', fontsize=14)
plt.ylabel('y(t)', fontsize=14)
plt.legend()
plt.grid(True)

plt.show()
